# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardo223-Mtz/Fundamentos_Python/blob/main/Copia_de_Unidad7_Python_sin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo-alinnco.jpg](data:image/jpeg;base64,...)
#
# # ***PROGRAMACIÓN PYTHON***
#
# ---

# %% [markdown]
# # **UNIDAD 7 - Visualización de datos.**
#
# ---
# ## **Matplotlib**.
#
# Es una biblioteca para crear visualizaciones estáticas, animadas e interactivas utilizando Python. Entre sus características se tiene:
#
# * Crea gráficas de calidad.
# * Las gráficas son interactivas.
# * El estilo visual puede personalizarse.
# * Se pueden exportar a muchos formatos.
# * Se integran aJupyter Lab e interfaces de usuario.
# * Utiliza arreglos ricos o de terceros.
#
# En su [sitio oficial](https://matplotlib.org/), es posible encontrar diversos recursos como docmentación, ejemplos, tutoriales, etc.
#
# Para instalar matplotlib es necesario hacero con el administrador de paquetes `pip`:
#
# `pip install matplotlib`
#
# O bien utilizando `conda`:
# `conda install matplotlib`
#
# Es común utlizar arreglos *numpy* y combinarlos con las capacidades de graficación de Matplolib.
#
# Crear una gráfica de líneas  con títulos y descripción de los ejer X y Y.

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-5.0, 5.0,0.0001)
y = np.sin(np.pi*x)

"Grafica"

plt.plot(x,y)
plt.title("Ejemplo de gráfica")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %% [markdown]
# Se pueden personlizar los indicadores de los valores a graficar, el color y tipo de la línea que se dibujará. Los valores aceptados para el tipo de línea son: `'-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'`.

# %%
x = np.arange(20)
y = np.random.randint(1,100,20)

plt.plot(x,y,marker = "o", color = "black", ls = "--")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %% [markdown]
# *Pandas* es una bibilioteca que es utilizada para trabajar con análisis y manipulaciónde datos. comúnmente se utiliza en combinación con Matplotlib para mostrar dichos datos de manera gŕafica.
# El objeto base para trabajar con *Pandas* es el *DataFrame*, que esencialmente es una estructura de datos bidimensional, similar a un arreglo o a una tabla con filas y columnas.
# Par amayor información sobre *Pandas", se puede consultar su [sitio oficial](https://pandas.pydata.org/).
# En algunos ejemplos posteriores, se utilizará *Pandas* y *numpy* para suministrar datos a *Matplotlib*.

# %%
import pandas as pd

n = 30
columns = ["Marca"+str(number) for number in range(1,5)]
date = pd.date_range(start = "2021-01-01", periods=n)

data = np.random.randint(low = 1, high = (100,300,45,771), size= (n,4))
df = pd.DataFrame(data, columns=columns, index = date)

plt.figure(figsize=(12,5))
plt.plot(df.index, df["Marca2"], c = "red", ls = "-")
plt.title("Marca A")
plt.xlabel("Fecha")
plt.ylabel("Valores")
plt.grid(True)
plt.show()

print(columns)
print("*************")
print(date)
print("*************")
print(data)
print("*************")
print(df)
# Out:
# ['Marca1', 'Marca2', 'Marca3', 'Marca4']
# *************
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16',
#                '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20',
#                '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-01-30'],
#               dtype='datetime64[ns]', freq='D')
# *************
# [[ 62 286  15 739]
#  [ 12 212  36 142]
#  [ 93  76  17 679]
#  [ 18 281  34 685]
#  [ 94 107   4 653]
#  [ 69  85  33 635]
#  [ 22 222  36  21]
#  [ 61 212  31 134]
#  [ 28 195  15 216]
#  [ 99 172  15 560]
#  [ 35 105   7 407]
#  [ 87   6  26 103]
#  [ 51 143  31 408]
#  [ 99  76  24 162]
#  [ 22 150  37 700]
#  [ 23 267  17 763]
#  [ 22 236  43 601]
#  [ 80  40  19  65]
#  [ 41  52  17 277]
#  [ 23 140  39 277]
#  [ 90 161  26 488]
#  [ 21 137  18 347]
#  [ 60 106  39   6]
#  [ 50 239   7 327]
#  [ 86  50  35  22]
#  [ 76 287  11 346]
#  [ 33 153  33   5]
#  [ 44 150  31 560]
#  [  8 233   4 240]
#  [  6 276  14 371]]
# *************
#             Marca1  Marca2  Marca3  Marca4
# 2021-01-01      62     286      15     739
# 2021-01-02      12     212      36     142
# 2021-01-03      93      76      17     679
# 2021-01-04      18     281      34     685
# 2021-01-05      94     107       4     653
# 2021-01-06      69      85      33     635
# 2021-01-07      22     222      36      21
# 2021-01-08      61     212      31     134
# 2021-01-09      28     195      15     216
# 2021-01-10      99     172      15     560
# 2021-01-11      35     105       7     407
# 2021-01-12      87       6      26     103
# 2021-01-13      51     143      31     408
# 2021-01-14      99      76      24     162
# 2021-01-15      22     150      37     700
# 2021-01-16      23     267      17     763
# 2021-01-17      22     236      43     601
# 2021-01-18      80      40      19      65
# 2021-01-19      41      52      17     277
# 2021-01-20      23     140      39     277
# 2021-01-21      90     161      26     488
# 2021-01-22      21     137      18     347
# 2021-01-23      60     106      39       6
# 2021-01-24      50     239       7     327
# 2021-01-25      86      50      35      22
# 2021-01-26      76     287      11     346
# 2021-01-27      33     153      33       5
# 2021-01-28      44     150      31     560
# 2021-01-29       8     233       4     240
# 2021-01-30       6     276      14     371

# %% [markdown]
# Con la función `plt.bar()` es posible crear gráficas de barras:

# %%
data = df.sum().sort_values(ascending=False)

plt.bar(x = data.index, height=data)
plt.title("Gráfica de Barras")
plt.xlabel("Marca")
plt.ylabel("Valores")
plt.savefig("graficavertical.jpeg")
plt.show()

# %% [markdown]
# Las gráficas de barras pueden ser también horizontales.
#
# El método `savefig()` se usa para guardar en el disco duro la gráfica creada en formato de imagen.

# %%
data = df.sum().sort_values(ascending=False)

plt.barh(y = data.index, width=data)
plt.title("Gráfica de Barras")
plt.xlabel("Marca")
plt.ylabel("Valores")
plt.savefig("graficavertical.jpeg")
plt.show()

# %% [markdown]
# Otra biblioteca que se usa comúnmente en combinación con *matplotlib* es *scikit-learn*. Está última esencialmente sirve para utiliar algoritmos de aprendizaje máquina de una manera realtivamente sencilla. Más información en su [sitio oficial](https://scikit-learn.org/stable/index.html).
#
# En el ejericio siguiente, se va a utilizar para dibujar un diagrama de dispersión con los marcadores indicados con el símbolo "^" y una opacidad de 0.3.

# %%
from sklearn.datasets import make_regression

x, y = make_regression(n_samples  =100 ,n_features=1,noise=20)
plt.scatter(x,y,color="black",alpha=0.3)
plt.title("Relacion entre X y Y")
plt.xlabel("Caracteristica")
plt.ylabel("Objetivo")
plt.grid(True, linestyle = "--", alpha = 0.5)
plt.show()

# %% [markdown]
# Para construir un histograma se usa la función `plt.hist()`.

# %%
data = np.random.normal(loc = 100, scale = 0.5, size = 100)
print(data)
plt.hist(x = data)
plt.title("Histograma")
# Out:
# [100.35662479 100.26299575  99.85044911  99.45948339 100.21900794
#   99.10972348 100.54900729  99.61967838  99.74985445  99.66808242
#   99.61834439 100.0251016   99.54498649  99.87957701 100.37294886
#   99.97441437 100.45888975 100.19913042 101.09196623  99.56217413
#   99.64329439 100.55342258  99.33075318  99.85450455 100.49750765
#   99.80128146  99.66921669  98.67677097  99.56761216 100.34993791
#  100.22915081 100.62540747  99.69872005 100.1460815  100.37876658
#  100.52190882  99.76147691  99.02392475 100.07407563 100.43214865
#  100.78168543  99.92507619  99.746068   100.37350651  99.20313366
#   99.94185021  99.68282513  99.99912421  99.07534621 100.35319097
#  100.95311442  99.87672017  99.45374261  99.65179639  98.63005691
#  100.0388076  100.19341647 100.46851192 100.61110912 100.19144668
#   99.61501367  99.79757666 100.61032777  99.76316428  99.76903133
#  100.34147534 100.46422365 101.35558155  99.70752381  99.56189184
#   99.94042961 100.10921116  99.98579657 100.61179857  98.79564373
#  100.71014568 100.07761949 100.265645   100.6936127   99.81527482
#   99.78258402  99.67229223  99.84303135  99.05818462  99.81778127
#   99.53139343 100.05828067  99.37498914 100.30105528  99.53201539
#  100.07940174 100.64585107  99.40986581  99.91251928  99.54522375
#   99.99166201  99.145941    99.66385025 100.3763101   99.62378118]
# Text(0.5, 1.0, 'Histograma')

# %% [markdown]
# En la gráfica siguiente se cambiará el tamaño de la fuente a 15 en los ejes y a 20 en el título. La función `plt.legend()` permitirá insertar una leyenda en el gráfico y con el argumento `loc`, se indicará la posición. Las opciones válidas para dicho argumento son: `best, 	upper right, upper left, lower left, lower right, right, center left, center right, lower center, upper center, center`.

# %%
x = np.arange(1,11)
y1 = x**2
y2 = x**3
y3 = x**4

plt.plot(y1,'o',y2,"o",y3,"bs")
plt.legend(["y1","y2","y3"], loc = "upper left")
plt.title("Valores", fontsize = 20)
plt.xlabel("x", fontsize = 15)
plt.ylabel("y", fontsize = 10)
plt.grid(True, linestyle = "--", alpha = 0.8)
plt.show()

# %% [markdown]
# Para crear una gráfica de barras apiladas, es necesario agregar en el mismo eje, los conjuntos de datos que se quieran mostrar.

# %%
marcaA = [283,456,234,432,270,160]
marcaB = [253,123,134,145,231,103]
meses = ["Enero","Febrero","Marzo","Abril","Mayo","Junio"]

plt.bar(x = meses, height=marcaA, color="blue", label="Marca_A")
plt.bar(x = meses, height=marcaB, color="red", label="Marca_B")
plt.title("Ingresos sobre el tiempo")
plt.show()

# %% [markdown]
# Para una gráfica de pastel, se tiene que usar la función `plt.pie()`:

# %%
marcaA = [283,456,234,432,270,160]
meses = ["Enero","Febrero","Marzo","Abril","Mayo","Junio"]
colores = ["red","blue","cyan","purple","orange","gray"]
plt.pie(marcaA, labels=meses, colors=colores)
plt.show()

# %% [markdown]
# También se le puede agregar sombra, una leyenda, los pocentajes correspondientes y separar cada segmento:

# %%
separacion = (0.1,0.1,0.2,0.1,0.1, 0.1)

plt.pie(marcaA, labels=meses, colors=colores, explode= separacion, shadow=True)
plt.show()

# %% [markdown]
# En el ejercicio siguiente, se va a crear un dataframe con valores al azar, se imprimirá la tabla y la gráfica correspondiente. Los valores cambiarán respecto al tiempo (cada mes). Cada columna será representada con un línea de color diferente.

# %%
np.random.seed(7)

data = np.random.randint(low =100, high=(250,300,500,1000), size = (12,4))
index = pd.date_range(start = "2025-01-01",periods=12, freq = "M")
df = pd.DataFrame(data, columns = list("ABCD"), index = index.month_name())


plt.plot(df)
plt.legend(df.columns, loc = "best")
plt.show()
# Out:
# /tmp/ipython-input-86-458857161.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   index = pd.date_range(start = "2025-01-01",periods=12, freq = "M")

# %% [markdown]
# com ose observa en el resultado anterior, la gráfica se nota un tanto ilegible dado el tamaño de la misma, es posible modificar lo anterior con rl argumento `figsize`. Por otra parte, si queremos modificar el l{imite del eje Y, se hace con la función `plt.ylimit()`. Modificar estos parámetros, mermitirá generar una mejor gráfica.

# %%
np.random.seed(7)

data = np.random.randint(low =100, high=(250,300,500,1000), size = (12,4))
index = pd.date_range(start = "2025-01-01",periods=12, freq = "M")
df = pd.DataFrame(data, columns = list("ABCD"), index = index.month_name())

plt.figure(figsize=(15,4))
plt.plot(df)
plt.title("Valores sobre el tiempo")
plt.legend(df.columns, loc = "best")
plt.ylim(0,1100)
plt.show()
# Out:
# /tmp/ipython-input-96-2382416180.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   index = pd.date_range(start = "2025-01-01",periods=12, freq = "M")

# %% [markdown]
# ***COMPARTE TUS REFLEXIONES DE LOS TEMAS VISTOS ANTERIORMENTE.***

# %% [markdown]
# ![Gracias_Allinco.jpg](data:image/jpeg;base64,...)
